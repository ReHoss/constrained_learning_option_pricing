# %%
# The line below allows to print all the outputs of a cell instead of only the last one
# %config InteractiveShell.ast_node_interactivity = "all"
import os
import pathlib
import sys

import matplotlib.pyplot as plt
import pandas as pd
import yaml

# %%
from_script = False

print(f"WARNING: This notebook is set with from_script = {from_script}.")

if from_script:
    # Get the path of the notebook config file from the environment variable
    path_config_notebook = os.environ["PATH_YAML_CONFIG"]
    # Load the notebook config file
    with open(path_config_notebook, "r") as file:
        dict_config_notebook = yaml.safe_load(file)
        print("The dict_config_notebook is:")
        print(dict_config_notebook)
    ID_XP_DATASET = dict_config_notebook["id_xp_dataset"]
    ID_XP = dict_config_notebook["id_xp"]
    PATH_PROJECT = pathlib.Path(dict_config_notebook["path_project"])
    DICT_FILTERS = dict_config_notebook.get("dict_filters", None)
    NAME_MLFLOW_STORE = dict_config_notebook.get(
        "name_mlflow_store", "mlruns_ruche_downloaded"
    )

    DEBUG_SIZE_FILTER = dict_config_notebook.get("debug_size_filter", None)
else:
    ID_XP_DATASET = 6
    ID_XP = 8
    PATH_PROJECT = pathlib.Path(
        "/home/hosseinkhan/Documents/work/phd/git_repositories/control_dde"
    )
    # DICT_FILTERS = {
    #     "env_name": ["cylinder"],
    #     "env_params_max_control": [0.0],
    #     "env_params_reynolds": [120.0, 90.0],
    # }
    DICT_FILTERS = {}
    DEBUG_SIZE_FILTER = None
    assert (
        DEBUG_SIZE_FILTER is None or DEBUG_SIZE_FILTER > 0
    ), "DEBUG_SIZE_FILTER must be positive."

    # DICT_FILTERS = None
    NAME_MLFLOW_STORE = "mlruns_ruche_downloaded"

# Add the path of the project to the sys.path in order to import
# the modules in the src folder
sys.path.insert(0, os.path.abspath(PATH_PROJECT))

# Define the paths
path_mlruns = pathlib.Path(f"{PATH_PROJECT}/data/{NAME_MLFLOW_STORE}")
path_experiment_dataset = pathlib.Path(f"{path_mlruns}/{ID_XP_DATASET}")
path_experiment = pathlib.Path(f"{path_mlruns}/{ID_XP}")
# Get all folder in the mlruns/id_xp directory except the folder 'tags'
# using pathlib and iter dir
list_id_hash = [
    path.name
    for path in path_experiment.iterdir()
    if path.is_dir() and path.name != "tags"
]
list_id_hash_dataset = [
    path.name
    for path in path_experiment_dataset.iterdir()
    if path.is_dir() and path.name != "tags"
]

print(f"Number of runs in the dataset: {len(list_id_hash_dataset)} \n")
print(f"Number of runs: {len(list_id_hash)} \n")
print(f"XP id dataset: {ID_XP_DATASET} \n")
print(f"XP id: {ID_XP} \n")

nested_dict_config_dataset = {}
nested_dict_config = {}
list_df_config_flattened_dataset = []
list_df_config_flattened = []


def check_xp_lifecycle(path_file: pathlib.Path):
    if not path_file.exists():
        raise FileNotFoundError(f"The file {path_file} does not exist.")
    if not path_file.is_file():
        raise FileNotFoundError(f"The path {path_file} is not a file.")
    # Load the yaml file
    with open(path_file, "r") as _file:
        dict_temp = yaml.safe_load(_file)
    # Check the lifecycle key
    assert dict_temp.get("lifecycle_stage") == "active", "The experiment is not active."


# Verify all experiments are done on the same environment:
path_xp = f"{path_mlruns}/{ID_XP}"
for name_id in list_id_hash:
    # Check file lifecycle
    list_glob_xp_metadata = list(pathlib.Path(f"{path_xp}/{name_id}").glob("meta.yaml"))
    assert len(list_glob_xp_metadata) != 0, "No metadata file in the directory."
    assert (
        len(list_glob_xp_metadata) == 1
    ), "More than one metadata file in the directory."
    check_xp_lifecycle(list_glob_xp_metadata[0])

    # Get the config file
    list_glob_config = list(
        pathlib.Path(f"{path_xp}/{name_id}/artifacts").glob("./config/*.yaml")
    )
    assert len(list_glob_config) != 0, "No config file in the directory."
    assert len(list_glob_config) == 1, "More than one config file in the directory."

    name_config_file = list_glob_config[0].name
    # Check if the file is a yaml file
    assert name_config_file.endswith(".yaml"), "File is not a yaml file."

    path_run_config_yaml = list_glob_config[0]
    with open(path_run_config_yaml, "r") as file:
        # Get the config file as a dictionary
        dict_config_temp = yaml.safe_load(file)
        # Add the config file to the nested dictionary
        nested_dict_config[name_id] = dict_config_temp
        # Flatten the config file for easier check
        list_df_config_flattened.append(pd.json_normalize(dict_config_temp, sep="_"))
    del dict_config_temp

path_xp_dataset = f"{path_mlruns}/{ID_XP_DATASET}"
for name_id in list_id_hash_dataset:
    list_glob_config = list(
        pathlib.Path(f"{path_xp_dataset}/{name_id}/generated_data").glob(
            "./config/*.yaml"
        )
    )
    assert len(list_glob_config) != 0, "No config file in the directory."
    assert len(list_glob_config) == 1, "More than one config file in the directory."

    name_config_file = list_glob_config[0].name
    # Check if the file is a yaml file
    assert name_config_file.endswith(".yaml"), "File is not a yaml file."

    path_run_config_yaml = list_glob_config[0]
    with open(path_run_config_yaml, "r") as file:
        # Get the config file as a dictionary
        dict_config_temp = yaml.safe_load(file)
        # Add the config file to the nested dictionary
        nested_dict_config_dataset[name_id] = dict_config_temp
        # Flatten the config file for easier check
        list_df_config_flattened_dataset.append(
            pd.json_normalize(dict_config_temp, sep="_")
        )
    del dict_config_temp
# Out:
# WARNING: This notebook is set with from_script = False.
# Number of runs in the dataset: 9
#
# Number of runs: 86
#
# XP id dataset: 6
#
# XP id: 8

# %% [markdown]
# ## DataFrames generation

# %% [markdown]
# ### DataFrame: Training config

# %%
df_trainining_config = (
    pd.concat(
        [
            df_config_flattened.assign(training_id=name_id)
            for name_id, df_config_flattened in zip(
                list_id_hash, list_df_config_flattened
            )
        ]
    )
    .set_index("training_id")
    .pipe(
        lambda df: df.astype(
            {col: "float" for col in df.select_dtypes(include="int").columns}
        )
    )
)

df_trainining_config.head(10)
# Out:
#                                   mlflow_experiment_name  seed  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8  2024_08_23_training_v2   0.0
# 1df2f67566fd42d28780873a2af7fe6e  2024_08_23_training_v2   0.0
# cf68fcd06e904244afc33b1a479ce44a  2024_08_23_training_v2   1.0
# cda31db8e9ea4e7f8c6fde42e097b683  2024_08_23_training_v2   1.0
# 3f318f4a4e8b4362b0303a8f702aa0ac  2024_08_23_training_v2   0.0
# 85363c1761704713b8aa3ca2a99c1ae0  2024_08_23_training_v2   0.0
# ef9e78d7a1614d44b364672b461869a2  2024_08_23_training_v2   0.0
# e80cb5b6c79c4786987a7e0994581a08  2024_08_23_training_v2   1.0
# 4102e29d9ab142258262f2676e8512fc  2024_08_23_training_v2   1.0
# 361bcedce66b43b9a5b5dcecf04434d7  2024_08_23_training_v2   1.0
#
#                                  data_normaliser_name  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8      standard_normal
# 1df2f67566fd42d28780873a2af7fe6e      standard_normal
# cf68fcd06e904244afc33b1a479ce44a      standard_normal
# cda31db8e9ea4e7f8c6fde42e097b683      standard_normal
# 3f318f4a4e8b4362b0303a8f702aa0ac      standard_normal
# 85363c1761704713b8aa3ca2a99c1ae0      standard_normal
# ef9e78d7a1614d44b364672b461869a2      standard_normal
# e80cb5b6c79c4786987a7e0994581a08      standard_normal
# 4102e29d9ab142258262f2676e8512fc      standard_normal
# 361bcedce66b43b9a5b5dcecf04434d7      standard_normal
#
#                                                               data_path_data_folder  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8  data/mlruns/6/8a10495b64e5407090d91eb01b46c5a7...
# 1df2f67566fd42d28780873a2af7fe6e  data/mlruns/6/5497e581024548e0b95621c4509a55ce...
# cf68fcd06e904244afc33b1a479ce44a  data/mlruns/6/87ec5e0fc69548d5ba0e69c0f4c8694c...
# cda31db8e9ea4e7f8c6fde42e097b683  data/mlruns/6/86c03c4c3740431dad24a5b4cc451c40...
# 3f318f4a4e8b4362b0303a8f702aa0ac  data/mlruns/6/86c03c4c3740431dad24a5b4cc451c40...
# 85363c1761704713b8aa3ca2a99c1ae0  data/mlruns/6/6f35c3230f39428c89bda3cae4ad3b7a...
# ef9e78d7a1614d44b364672b461869a2  data/mlruns/6/6f35c3230f39428c89bda3cae4ad3b7a...
# e80cb5b6c79c4786987a7e0994581a08  data/mlruns/6/581bd62a053a4ddf8879fb65d041aba7...
# 4102e29d9ab142258262f2676e8512fc  data/mlruns/6/86c03c4c3740431dad24a5b4cc451c40...
# 361bcedce66b43b9a5b5dcecf04434d7  data/mlruns/6/cf34cb80cddc497c900dbd62e9958e60...
#
#                                  model_name model_params_activation  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8      ncdde                    relu
# 1df2f67566fd42d28780873a2af7fe6e       node                    relu
# cf68fcd06e904244afc33b1a479ce44a       ncde                    relu
# cda31db8e9ea4e7f8c6fde42e097b683       node                    relu
# 3f318f4a4e8b4362b0303a8f702aa0ac      ncdde                    relu
# 85363c1761704713b8aa3ca2a99c1ae0       ndde                    relu
# ef9e78d7a1614d44b364672b461869a2       node                    relu
# e80cb5b6c79c4786987a7e0994581a08       ncde                    relu
# 4102e29d9ab142258262f2676e8512fc       ndde                    relu
# 361bcedce66b43b9a5b5dcecf04434d7      ncdde                    relu
#
#                                   model_params_depth  model_params_dropout  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                 2.0                   0.0
# 1df2f67566fd42d28780873a2af7fe6e                 2.0                   0.0
# cf68fcd06e904244afc33b1a479ce44a                 2.0                   0.0
# cda31db8e9ea4e7f8c6fde42e097b683                 2.0                   0.0
# 3f318f4a4e8b4362b0303a8f702aa0ac                 2.0                   0.0
# 85363c1761704713b8aa3ca2a99c1ae0                 2.0                   0.0
# ef9e78d7a1614d44b364672b461869a2                 2.0                   0.0
# e80cb5b6c79c4786987a7e0994581a08                 2.0                   0.0
# 4102e29d9ab142258262f2676e8512fc                 2.0                   0.0
# 361bcedce66b43b9a5b5dcecf04434d7                 2.0                   0.0
#
#                                  model_params_final_activation  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                      identity
# 1df2f67566fd42d28780873a2af7fe6e                      identity
# cf68fcd06e904244afc33b1a479ce44a                      identity
# cda31db8e9ea4e7f8c6fde42e097b683                      identity
# 3f318f4a4e8b4362b0303a8f702aa0ac                      identity
# 85363c1761704713b8aa3ca2a99c1ae0                      identity
# ef9e78d7a1614d44b364672b461869a2                      identity
# e80cb5b6c79c4786987a7e0994581a08                      identity
# 4102e29d9ab142258262f2676e8512fc                      identity
# 361bcedce66b43b9a5b5dcecf04434d7                      identity
#
#                                   model_params_n_delays  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                    1.0
# 1df2f67566fd42d28780873a2af7fe6e                    NaN
# cf68fcd06e904244afc33b1a479ce44a                    NaN
# cda31db8e9ea4e7f8c6fde42e097b683                    NaN
# 3f318f4a4e8b4362b0303a8f702aa0ac                    1.0
# 85363c1761704713b8aa3ca2a99c1ae0                    1.0
# ef9e78d7a1614d44b364672b461869a2                    NaN
# e80cb5b6c79c4786987a7e0994581a08                    NaN
# 4102e29d9ab142258262f2676e8512fc                    1.0
# 361bcedce66b43b9a5b5dcecf04434d7                    1.0
#
#                                   model_params_width_size trainer_name  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                     64.0        ncdde
# 1df2f67566fd42d28780873a2af7fe6e                     64.0         node
# cf68fcd06e904244afc33b1a479ce44a                     64.0         ncde
# cda31db8e9ea4e7f8c6fde42e097b683                     64.0         node
# 3f318f4a4e8b4362b0303a8f702aa0ac                     64.0        ncdde
# 85363c1761704713b8aa3ca2a99c1ae0                     64.0         ndde
# ef9e78d7a1614d44b364672b461869a2                     64.0         node
# e80cb5b6c79c4786987a7e0994581a08                     64.0         ncde
# 4102e29d9ab142258262f2676e8512fc                     64.0         ndde
# 361bcedce66b43b9a5b5dcecf04434d7                     64.0        ncdde
#
#                                   trainer_params_bool_discretize_then_optimize  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                                          True
# 1df2f67566fd42d28780873a2af7fe6e                                          True
# cf68fcd06e904244afc33b1a479ce44a                                          True
# cda31db8e9ea4e7f8c6fde42e097b683                                          True
# 3f318f4a4e8b4362b0303a8f702aa0ac                                          True
# 85363c1761704713b8aa3ca2a99c1ae0                                          True
# ef9e78d7a1614d44b364672b461869a2                                          True
# e80cb5b6c79c4786987a7e0994581a08                                          True
# 4102e29d9ab142258262f2676e8512fc                                          True
# 361bcedce66b43b9a5b5dcecf04434d7                                          True
#
#                                   trainer_params_lr_final  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                    0.001
# 1df2f67566fd42d28780873a2af7fe6e                    0.001
# cf68fcd06e904244afc33b1a479ce44a                    0.001
# cda31db8e9ea4e7f8c6fde42e097b683                    0.001
# 3f318f4a4e8b4362b0303a8f702aa0ac                    0.001
# 85363c1761704713b8aa3ca2a99c1ae0                    0.001
# ef9e78d7a1614d44b364672b461869a2                    0.001
# e80cb5b6c79c4786987a7e0994581a08                    0.001
# 4102e29d9ab142258262f2676e8512fc                    0.001
# 361bcedce66b43b9a5b5dcecf04434d7                    0.001
#
#                                   trainer_params_lr_init  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                   0.001
# 1df2f67566fd42d28780873a2af7fe6e                   0.001
# cf68fcd06e904244afc33b1a479ce44a                   0.001
# cda31db8e9ea4e7f8c6fde42e097b683                   0.001
# 3f318f4a4e8b4362b0303a8f702aa0ac                   0.001
# 85363c1761704713b8aa3ca2a99c1ae0                   0.001
# ef9e78d7a1614d44b364672b461869a2                   0.001
# e80cb5b6c79c4786987a7e0994581a08                   0.001
# 4102e29d9ab142258262f2676e8512fc                   0.001
# 361bcedce66b43b9a5b5dcecf04434d7                   0.001
#
#                                   trainer_params_max_epochs  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                     4000.0
# 1df2f67566fd42d28780873a2af7fe6e                     4000.0
# cf68fcd06e904244afc33b1a479ce44a                     4000.0
# cda31db8e9ea4e7f8c6fde42e097b683                     4000.0
# 3f318f4a4e8b4362b0303a8f702aa0ac                     4000.0
# 85363c1761704713b8aa3ca2a99c1ae0                     4000.0
# ef9e78d7a1614d44b364672b461869a2                     4000.0
# e80cb5b6c79c4786987a7e0994581a08                     4000.0
# 4102e29d9ab142258262f2676e8512fc                     4000.0
# 361bcedce66b43b9a5b5dcecf04434d7                     4000.0
#
#                                  trainer_params_name_node_interface  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                           torchdde
# 1df2f67566fd42d28780873a2af7fe6e                           torchdde
# cf68fcd06e904244afc33b1a479ce44a                           torchdde
# cda31db8e9ea4e7f8c6fde42e097b683                           torchdde
# 3f318f4a4e8b4362b0303a8f702aa0ac                           torchdde
# 85363c1761704713b8aa3ca2a99c1ae0                           torchdde
# ef9e78d7a1614d44b364672b461869a2                           torchdde
# e80cb5b6c79c4786987a7e0994581a08                           torchdde
# 4102e29d9ab142258262f2676e8512fc                           torchdde
# 361bcedce66b43b9a5b5dcecf04434d7                           torchdde
#
#                                   trainer_params_pct_trajectory_size  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                                 1.0
# 1df2f67566fd42d28780873a2af7fe6e                                 1.0
# cf68fcd06e904244afc33b1a479ce44a                                 1.0
# cda31db8e9ea4e7f8c6fde42e097b683                                 1.0
# 3f318f4a4e8b4362b0303a8f702aa0ac                                 1.0
# 85363c1761704713b8aa3ca2a99c1ae0                                 1.0
# ef9e78d7a1614d44b364672b461869a2                                 1.0
# e80cb5b6c79c4786987a7e0994581a08                                 1.0
# 4102e29d9ab142258262f2676e8512fc                                 1.0
# 361bcedce66b43b9a5b5dcecf04434d7                                 1.0
#
#                                   trainer_params_rate_test_set_size  \
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                                0.1
# 1df2f67566fd42d28780873a2af7fe6e                                0.1
# cf68fcd06e904244afc33b1a479ce44a                                0.1
# cda31db8e9ea4e7f8c6fde42e097b683                                0.1
# 3f318f4a4e8b4362b0303a8f702aa0ac                                0.1
# 85363c1761704713b8aa3ca2a99c1ae0                                0.1
# ef9e78d7a1614d44b364672b461869a2                                0.1
# e80cb5b6c79c4786987a7e0994581a08                                0.1
# 4102e29d9ab142258262f2676e8512fc                                0.1
# 361bcedce66b43b9a5b5dcecf04434d7                                0.1
#
#                                  trainer_params_solver
# training_id
# 61af45e340174a0fb2108f54c97ee0f8                   rk4
# 1df2f67566fd42d28780873a2af7fe6e                   rk4
# cf68fcd06e904244afc33b1a479ce44a                   rk4
# cda31db8e9ea4e7f8c6fde42e097b683                   rk4
# 3f318f4a4e8b4362b0303a8f702aa0ac                   rk4
# 85363c1761704713b8aa3ca2a99c1ae0                   rk4
# ef9e78d7a1614d44b364672b461869a2                   rk4
# e80cb5b6c79c4786987a7e0994581a08                   rk4
# 4102e29d9ab142258262f2676e8512fc                   rk4
# 361bcedce66b43b9a5b5dcecf04434d7                   rk4

# %% [markdown]
# ### DataFrame: Dataset config

# %%
df_dataset_config = (
    pd.concat(
        [
            df_config_flattened.assign(dataset_id=name_id)
            for name_id, df_config_flattened in zip(
                list_id_hash_dataset, list_df_config_flattened_dataset
            )
        ]
    )
    .set_index("dataset_id")
    .pipe(
        lambda df: df.astype(
            {col: "float" for col in df.select_dtypes(include="int").columns}
        )
    )
)

df_dataset_config.head(10)
# Out:
#                                        mlflow_experiment_name  seed  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40  2024_08_12_training_data_v2   0.0
# 1f43506f737b4ca6ac16ab3335c6e4cd  2024_08_12_training_data_v2   0.0
# 581bd62a053a4ddf8879fb65d041aba7  2024_08_12_training_data_v2   0.0
# 5497e581024548e0b95621c4509a55ce  2024_08_12_training_data_v2   0.0
# 87ec5e0fc69548d5ba0e69c0f4c8694c  2024_08_12_training_data_v2   0.0
# cf34cb80cddc497c900dbd62e9958e60  2024_08_12_training_data_v2   0.0
# 8b885c1be6c147ceb9811fce04a7fa01  2024_08_12_training_data_v2   0.0
# 8a10495b64e5407090d91eb01b46c5a7  2024_08_12_training_data_v2   0.0
# 6f35c3230f39428c89bda3cae4ad3b7a  2024_08_12_training_data_v2   0.0
#
#                                  data_control_type  data_num_steps  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40           uniform           100.0
# 1f43506f737b4ca6ac16ab3335c6e4cd           uniform           100.0
# 581bd62a053a4ddf8879fb65d041aba7           uniform           100.0
# 5497e581024548e0b95621c4509a55ce           uniform           100.0
# 87ec5e0fc69548d5ba0e69c0f4c8694c           uniform           100.0
# cf34cb80cddc497c900dbd62e9958e60           uniform           100.0
# 8b885c1be6c147ceb9811fce04a7fa01           uniform           100.0
# 8a10495b64e5407090d91eb01b46c5a7           uniform           100.0
# 6f35c3230f39428c89bda3cae4ad3b7a           uniform           100.0
#
#                                   data_num_trajectories  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40                  400.0
# 1f43506f737b4ca6ac16ab3335c6e4cd                  400.0
# 581bd62a053a4ddf8879fb65d041aba7                  400.0
# 5497e581024548e0b95621c4509a55ce                  400.0
# 87ec5e0fc69548d5ba0e69c0f4c8694c                  400.0
# cf34cb80cddc497c900dbd62e9958e60                  400.0
# 8b885c1be6c147ceb9811fce04a7fa01                  400.0
# 8a10495b64e5407090d91eb01b46c5a7                  400.0
# 6f35c3230f39428c89bda3cae4ad3b7a                  400.0
#
#                                               data_type      env_name  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40  multiple_trajectories  mackey_glass
# 1f43506f737b4ca6ac16ab3335c6e4cd  multiple_trajectories     vanderpol
# 581bd62a053a4ddf8879fb65d041aba7  multiple_trajectories     vanderpol
# 5497e581024548e0b95621c4509a55ce  multiple_trajectories      pendulum
# 87ec5e0fc69548d5ba0e69c0f4c8694c  multiple_trajectories  mackey_glass
# cf34cb80cddc497c900dbd62e9958e60  multiple_trajectories  mackey_glass
# 8b885c1be6c147ceb9811fce04a7fa01  multiple_trajectories     vanderpol
# 8a10495b64e5407090d91eb01b46c5a7  multiple_trajectories      pendulum
# 6f35c3230f39428c89bda3cae4ad3b7a  multiple_trajectories      pendulum
#
#                                   env_params_beta  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40              2.0
# 1f43506f737b4ca6ac16ab3335c6e4cd              NaN
# 581bd62a053a4ddf8879fb65d041aba7              NaN
# 5497e581024548e0b95621c4509a55ce              NaN
# 87ec5e0fc69548d5ba0e69c0f4c8694c              2.0
# cf34cb80cddc497c900dbd62e9958e60              2.0
# 8b885c1be6c147ceb9811fce04a7fa01              NaN
# 8a10495b64e5407090d91eb01b46c5a7              NaN
# 6f35c3230f39428c89bda3cae4ad3b7a              NaN
#
#                                   env_params_delay_observation  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40                          0.01
# 1f43506f737b4ca6ac16ab3335c6e4cd                          0.01
# 581bd62a053a4ddf8879fb65d041aba7                          0.10
# 5497e581024548e0b95621c4509a55ce                          0.01
# 87ec5e0fc69548d5ba0e69c0f4c8694c                          0.10
# cf34cb80cddc497c900dbd62e9958e60                          0.00
# 8b885c1be6c147ceb9811fce04a7fa01                          0.00
# 8a10495b64e5407090d91eb01b46c5a7                          0.00
# 6f35c3230f39428c89bda3cae4ad3b7a                          0.10
#
#                                   env_params_dict_initial_condition_std  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40                                    0.1
# 1f43506f737b4ca6ac16ab3335c6e4cd                                    0.1
# 581bd62a053a4ddf8879fb65d041aba7                                    0.1
# 5497e581024548e0b95621c4509a55ce                                    0.1
# 87ec5e0fc69548d5ba0e69c0f4c8694c                                    0.1
# cf34cb80cddc497c900dbd62e9958e60                                    0.1
# 8b885c1be6c147ceb9811fce04a7fa01                                    0.1
# 8a10495b64e5407090d91eb01b46c5a7                                    0.1
# 6f35c3230f39428c89bda3cae4ad3b7a                                    0.1
#
#                                  env_params_dict_initial_condition_type  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40                                nonzero
# 1f43506f737b4ca6ac16ab3335c6e4cd                                   zero
# 581bd62a053a4ddf8879fb65d041aba7                                   zero
# 5497e581024548e0b95621c4509a55ce                                 bottom
# 87ec5e0fc69548d5ba0e69c0f4c8694c                                nonzero
# cf34cb80cddc497c900dbd62e9958e60                                nonzero
# 8b885c1be6c147ceb9811fce04a7fa01                                   zero
# 8a10495b64e5407090d91eb01b46c5a7                                 bottom
# 6f35c3230f39428c89bda3cae4ad3b7a                                 bottom
#
#                                   env_params_dt  env_params_gamma  \
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40            0.1               1.0
# 1f43506f737b4ca6ac16ab3335c6e4cd            0.1               NaN
# 581bd62a053a4ddf8879fb65d041aba7            0.1               NaN
# 5497e581024548e0b95621c4509a55ce            0.1               NaN
# 87ec5e0fc69548d5ba0e69c0f4c8694c            0.1               1.0
# cf34cb80cddc497c900dbd62e9958e60            0.1               1.0
# 8b885c1be6c147ceb9811fce04a7fa01            0.1               NaN
# 8a10495b64e5407090d91eb01b46c5a7            0.1               NaN
# 6f35c3230f39428c89bda3cae4ad3b7a            0.1               NaN
#
#                                   env_params_n  env_params_tau
# dataset_id
# 86c03c4c3740431dad24a5b4cc451c40           7.0             3.0
# 1f43506f737b4ca6ac16ab3335c6e4cd           NaN             NaN
# 581bd62a053a4ddf8879fb65d041aba7           NaN             NaN
# 5497e581024548e0b95621c4509a55ce           NaN             NaN
# 87ec5e0fc69548d5ba0e69c0f4c8694c           7.0             3.0
# cf34cb80cddc497c900dbd62e9958e60           7.0             3.0
# 8b885c1be6c147ceb9811fce04a7fa01           NaN             NaN
# 8a10495b64e5407090d91eb01b46c5a7           NaN             NaN
# 6f35c3230f39428c89bda3cae4ad3b7a           NaN             NaN

# %%
print("Unique values of the dataset DataFrame")
print(df_dataset_config.nunique())
for column in df_dataset_config.columns:
    print(f"{column}: {df_dataset_config[column].unique()}")
# Out:
# Unique values of the dataset DataFrame
# mlflow_experiment_name                    1
# seed                                      1
# data_control_type                         1
# data_num_steps                            1
# data_num_trajectories                     1
# data_type                                 1
# env_name                                  3
# env_params_beta                           1
# env_params_delay_observation              3
# env_params_dict_initial_condition_std     1
# env_params_dict_initial_condition_type    3
# env_params_dt                             1
# env_params_gamma                          1
# env_params_n                              1
# env_params_tau                            1
# dtype: int64
# mlflow_experiment_name: ['2024_08_12_training_data_v2']
# seed: [0.]
# data_control_type: ['uniform']
# data_num_steps: [100.]
# data_num_trajectories: [400.]
# data_type: ['multiple_trajectories']
# env_name: ['mackey_glass' 'vanderpol' 'pendulum']
# env_params_beta: [ 2. nan]
# env_params_delay_observation: [0.01 0.1  0.  ]
# env_params_dict_initial_condition_std: [0.1]
# env_params_dict_initial_condition_type: ['nonzero' 'zero' 'bottom']
# env_params_dt: [0.1]
# env_params_gamma: [ 1. nan]
# env_params_n: [ 7. nan]
# env_params_tau: [ 3. nan]

# %% [markdown]
# ### DataFrame: Training and dataset config merged

# %% [markdown]
# #### Filtering DataFrame

# %%
# Filtering function based on the DICT_FILTERS
def filter_dataframe(df: pd.DataFrame):
    mask = pd.Series([True] * len(df), index=df.index)
    if DICT_FILTERS is None:
        return mask
    else:
        for key, list_values in DICT_FILTERS.items():
            if key in df.columns:
                mask = mask & df[key].isin(list_values)
            else:
                print(f"Warning: The key {key} is not in the config file.")
    return mask


df_training_dataset_merged = (
    df_trainining_config.assign(
        dataset_id=lambda _x: _x.data_path_data_folder.str.extract(
            rf"{ID_XP_DATASET}/(.*?)/generated_data"
        )
    )
    .join(df_dataset_config, on="dataset_id", rsuffix="_dataset")
    .fillna({"model_params_n_delays": 0.0})
    .drop(columns=["data_path_data_folder"])
    # .loc[lambda df: filter_dataframe(df)]
)

# %%
df_training_dataset_merged.shape
# Out:
# (86, 35)

# %%
df_training_dataset_merged.sample(frac=1).head(10)
# Out:
#                                   mlflow_experiment_name  seed  \
# training_id
# 942941703cb04001bde84e7e7b5de832  2024_08_23_training_v2   1.0
# 8cbb50698abf47878f5203314bf4f20e  2024_08_23_training_v2   1.0
# b3d62fd26f2147b89f83a917b03981a1  2024_08_23_training_v2   1.0
# 61af45e340174a0fb2108f54c97ee0f8  2024_08_23_training_v2   0.0
# 5a0197dba4df4d23a33dc871705a6d68  2024_08_23_training_v2   1.0
# cbe0c7dd680e46b9966e355f4c2cc53d  2024_08_23_training_v2   0.0
# 3ee80e854a1840c1a022f2bbc4cfea9e  2024_08_23_training_v2   0.0
# e372e80a17e14309af440dabeadf73e7  2024_08_23_training_v2   0.0
# c23c47485e3548a6a5ac145ce343b639  2024_08_23_training_v2   0.0
# 25ae5b0a0633461390e9a6db7ef307cc  2024_08_23_training_v2   1.0
#
#                                  data_normaliser_name model_name  \
# training_id
# 942941703cb04001bde84e7e7b5de832      standard_normal       ncde
# 8cbb50698abf47878f5203314bf4f20e      standard_normal      ncdde
# b3d62fd26f2147b89f83a917b03981a1      standard_normal       ncde
# 61af45e340174a0fb2108f54c97ee0f8      standard_normal      ncdde
# 5a0197dba4df4d23a33dc871705a6d68      standard_normal       ndde
# cbe0c7dd680e46b9966e355f4c2cc53d      standard_normal       ndde
# 3ee80e854a1840c1a022f2bbc4cfea9e      standard_normal       node
# e372e80a17e14309af440dabeadf73e7      standard_normal       ndde
# c23c47485e3548a6a5ac145ce343b639      standard_normal       ndde
# 25ae5b0a0633461390e9a6db7ef307cc      standard_normal       node
#
#                                  model_params_activation  model_params_depth  \
# training_id
# 942941703cb04001bde84e7e7b5de832                    relu                 2.0
# 8cbb50698abf47878f5203314bf4f20e                    relu                 2.0
# b3d62fd26f2147b89f83a917b03981a1                    relu                 2.0
# 61af45e340174a0fb2108f54c97ee0f8                    relu                 2.0
# 5a0197dba4df4d23a33dc871705a6d68                    relu                 2.0
# cbe0c7dd680e46b9966e355f4c2cc53d                    relu                 2.0
# 3ee80e854a1840c1a022f2bbc4cfea9e                    relu                 2.0
# e372e80a17e14309af440dabeadf73e7                    relu                 2.0
# c23c47485e3548a6a5ac145ce343b639                    relu                 2.0
# 25ae5b0a0633461390e9a6db7ef307cc                    relu                 2.0
#
#                                   model_params_dropout  \
# training_id
# 942941703cb04001bde84e7e7b5de832                   0.0
# 8cbb50698abf47878f5203314bf4f20e                   0.0
# b3d62fd26f2147b89f83a917b03981a1                   0.0
# 61af45e340174a0fb2108f54c97ee0f8                   0.0
# 5a0197dba4df4d23a33dc871705a6d68                   0.0
# cbe0c7dd680e46b9966e355f4c2cc53d                   0.0
# 3ee80e854a1840c1a022f2bbc4cfea9e                   0.0
# e372e80a17e14309af440dabeadf73e7                   0.0
# c23c47485e3548a6a5ac145ce343b639                   0.0
# 25ae5b0a0633461390e9a6db7ef307cc                   0.0
#
#                                  model_params_final_activation  \
# training_id
# 942941703cb04001bde84e7e7b5de832                      identity
# 8cbb50698abf47878f5203314bf4f20e                      identity
# b3d62fd26f2147b89f83a917b03981a1                      identity
# 61af45e340174a0fb2108f54c97ee0f8                      identity
# 5a0197dba4df4d23a33dc871705a6d68                      identity
# cbe0c7dd680e46b9966e355f4c2cc53d                      identity
# 3ee80e854a1840c1a022f2bbc4cfea9e                      identity
# e372e80a17e14309af440dabeadf73e7                      identity
# c23c47485e3548a6a5ac145ce343b639                      identity
# 25ae5b0a0633461390e9a6db7ef307cc                      identity
#
#                                   model_params_n_delays  \
# training_id
# 942941703cb04001bde84e7e7b5de832                    0.0
# 8cbb50698abf47878f5203314bf4f20e                    1.0
# b3d62fd26f2147b89f83a917b03981a1                    0.0
# 61af45e340174a0fb2108f54c97ee0f8                    1.0
# 5a0197dba4df4d23a33dc871705a6d68                    1.0
# cbe0c7dd680e46b9966e355f4c2cc53d                    1.0
# 3ee80e854a1840c1a022f2bbc4cfea9e                    0.0
# e372e80a17e14309af440dabeadf73e7                    1.0
# c23c47485e3548a6a5ac145ce343b639                    1.0
# 25ae5b0a0633461390e9a6db7ef307cc                    0.0
#
#                                   model_params_width_size  ...  \
# training_id                                                ...
# 942941703cb04001bde84e7e7b5de832                     64.0  ...
# 8cbb50698abf47878f5203314bf4f20e                     64.0  ...
# b3d62fd26f2147b89f83a917b03981a1                     64.0  ...
# 61af45e340174a0fb2108f54c97ee0f8                     64.0  ...
# 5a0197dba4df4d23a33dc871705a6d68                     64.0  ...
# cbe0c7dd680e46b9966e355f4c2cc53d                     64.0  ...
# 3ee80e854a1840c1a022f2bbc4cfea9e                     64.0  ...
# e372e80a17e14309af440dabeadf73e7                     64.0  ...
# c23c47485e3548a6a5ac145ce343b639                     64.0  ...
# 25ae5b0a0633461390e9a6db7ef307cc                     64.0  ...
#
#                                               data_type      env_name  \
# training_id
# 942941703cb04001bde84e7e7b5de832  multiple_trajectories      pendulum
# 8cbb50698abf47878f5203314bf4f20e  multiple_trajectories  mackey_glass
# b3d62fd26f2147b89f83a917b03981a1  multiple_trajectories  mackey_glass
# 61af45e340174a0fb2108f54c97ee0f8  multiple_trajectories      pendulum
# 5a0197dba4df4d23a33dc871705a6d68  multiple_trajectories     vanderpol
# cbe0c7dd680e46b9966e355f4c2cc53d  multiple_trajectories     vanderpol
# 3ee80e854a1840c1a022f2bbc4cfea9e  multiple_trajectories     vanderpol
# e372e80a17e14309af440dabeadf73e7  multiple_trajectories      pendulum
# c23c47485e3548a6a5ac145ce343b639  multiple_trajectories      pendulum
# 25ae5b0a0633461390e9a6db7ef307cc  multiple_trajectories     vanderpol
#
#                                   env_params_beta  \
# training_id
# 942941703cb04001bde84e7e7b5de832              NaN
# 8cbb50698abf47878f5203314bf4f20e              2.0
# b3d62fd26f2147b89f83a917b03981a1              2.0
# 61af45e340174a0fb2108f54c97ee0f8              NaN
# 5a0197dba4df4d23a33dc871705a6d68              NaN
# cbe0c7dd680e46b9966e355f4c2cc53d              NaN
# 3ee80e854a1840c1a022f2bbc4cfea9e              NaN
# e372e80a17e14309af440dabeadf73e7              NaN
# c23c47485e3548a6a5ac145ce343b639              NaN
# 25ae5b0a0633461390e9a6db7ef307cc              NaN
#
#                                   env_params_delay_observation  \
# training_id
# 942941703cb04001bde84e7e7b5de832                          0.00
# 8cbb50698abf47878f5203314bf4f20e                          0.10
# b3d62fd26f2147b89f83a917b03981a1                          0.00
# 61af45e340174a0fb2108f54c97ee0f8                          0.00
# 5a0197dba4df4d23a33dc871705a6d68                          0.01
# cbe0c7dd680e46b9966e355f4c2cc53d                          0.00
# 3ee80e854a1840c1a022f2bbc4cfea9e                          0.00
# e372e80a17e14309af440dabeadf73e7                          0.01
# c23c47485e3548a6a5ac145ce343b639                          0.00
# 25ae5b0a0633461390e9a6db7ef307cc                          0.10
#
#                                   env_params_dict_initial_condition_std  \
# training_id
# 942941703cb04001bde84e7e7b5de832                                    0.1
# 8cbb50698abf47878f5203314bf4f20e                                    0.1
# b3d62fd26f2147b89f83a917b03981a1                                    0.1
# 61af45e340174a0fb2108f54c97ee0f8                                    0.1
# 5a0197dba4df4d23a33dc871705a6d68                                    0.1
# cbe0c7dd680e46b9966e355f4c2cc53d                                    0.1
# 3ee80e854a1840c1a022f2bbc4cfea9e                                    0.1
# e372e80a17e14309af440dabeadf73e7                                    0.1
# c23c47485e3548a6a5ac145ce343b639                                    0.1
# 25ae5b0a0633461390e9a6db7ef307cc                                    0.1
#
#                                  env_params_dict_initial_condition_type  \
# training_id
# 942941703cb04001bde84e7e7b5de832                                 bottom
# 8cbb50698abf47878f5203314bf4f20e                                nonzero
# b3d62fd26f2147b89f83a917b03981a1                                nonzero
# 61af45e340174a0fb2108f54c97ee0f8                                 bottom
# 5a0197dba4df4d23a33dc871705a6d68                                   zero
# cbe0c7dd680e46b9966e355f4c2cc53d                                   zero
# 3ee80e854a1840c1a022f2bbc4cfea9e                                   zero
# e372e80a17e14309af440dabeadf73e7                                 bottom
# c23c47485e3548a6a5ac145ce343b639                                 bottom
# 25ae5b0a0633461390e9a6db7ef307cc                                   zero
#
#                                   env_params_dt  env_params_gamma  \
# training_id
# 942941703cb04001bde84e7e7b5de832            0.1               NaN
# 8cbb50698abf47878f5203314bf4f20e            0.1               1.0
# b3d62fd26f2147b89f83a917b03981a1            0.1               1.0
# 61af45e340174a0fb2108f54c97ee0f8            0.1               NaN
# 5a0197dba4df4d23a33dc871705a6d68            0.1               NaN
# cbe0c7dd680e46b9966e355f4c2cc53d            0.1               NaN
# 3ee80e854a1840c1a022f2bbc4cfea9e            0.1               NaN
# e372e80a17e14309af440dabeadf73e7            0.1               NaN
# c23c47485e3548a6a5ac145ce343b639            0.1               NaN
# 25ae5b0a0633461390e9a6db7ef307cc            0.1               NaN
#
#                                  env_params_n env_params_tau
# training_id
# 942941703cb04001bde84e7e7b5de832          NaN            NaN
# 8cbb50698abf47878f5203314bf4f20e          7.0            3.0
# b3d62fd26f2147b89f83a917b03981a1          7.0            3.0
# 61af45e340174a0fb2108f54c97ee0f8          NaN            NaN
# 5a0197dba4df4d23a33dc871705a6d68          NaN            NaN
# cbe0c7dd680e46b9966e355f4c2cc53d          NaN            NaN
# 3ee80e854a1840c1a022f2bbc4cfea9e          NaN            NaN
# e372e80a17e14309af440dabeadf73e7          NaN            NaN
# c23c47485e3548a6a5ac145ce343b639          NaN            NaN
# 25ae5b0a0633461390e9a6db7ef307cc          NaN            NaN
#
# [10 rows x 35 columns]

# %%
DICT_COL_DISPLAY_NAME = {
    "env_params_delay_observation": "$\\tau$",
    "env_params_mesh": "Mesh",
    "env_name": "Env",
    "trainer_name": "Trainer",
    "data_type": "Data type",
    "value": "$\\mathcal{L}$",  # TODO: Check if I can replace by the right symbol
    "model_name": "Model",
    "metric": "Metric",
    "step": "Epochs",
}

DICT_VALUE_DISPLAY_NAME = {
    "node": "NODE",
    "ncde": "NCDE",
    "ndde": "NDDE",
    "ncdde": "NCDDE",
    "mean_loss_over_batches/train": "Train",
    "mean_loss_over_batches/eval": "Validation",
    "mackey_glass": "Mackey-Glass",
    "pendulum": "Pendulum",
}

COLOR_PALETTE = {
    "NODE": "forestgreen",
    "NCDE": "limegreen",
    "NDDE": "blue",
    "NCDDE": "skyblue",
}

plt.style.use("data/matplotlib_config/stylesheet.mplstyle")

# %%
# Loop over the subDataFrame determined byt the environment

for name_env, df_env in df_training_dataset_merged.groupby("env_name"):
    print(df_env.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Loop over the subDataFrame determined byt the environment
#       3 for name_env, df_env in df_training_dataset_merged.groupby("env_name"):
# ----> 4     print(df_env.shape)
#
# Cell In[13], line 4
#       1 # Loop over the subDataFrame determined byt the environment
#       3 for name_env, df_env in df_training_dataset_merged.groupby("env_name"):
# ----> 4     print(df_env.shape)
#
# File /snap/pycharm-professional/440/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File /snap/pycharm-professional/440/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File /snap/pycharm-professional/440/plugins/python-ce/helpers/pydev/pydevd.py:1220, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1217         from_this_thread.append(frame_id)
#    1219 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1220     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /snap/pycharm-professional/440/plugins/python-ce/helpers/pydev/pydevd.py:1235, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1232             self._call_mpl_hook()
#    1234         self.process_internal_commands()
# -> 1235         time.sleep(0.01)
#    1237 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1239 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
(
    df_training_dataset_merged[df_training_dataset_merged["env_name"] == "mackey_glass"]
    .loc[lambda df: df["seed"] == 1]
    # .duplicated()
    .shape
)
# Out:
# (13, 35)

# %% [markdown]
# ## Debugging

# %%
for name_env in df_training_dataset_merged["env_name"].unique():
    print(name_env)
    print(
        df_training_dataset_merged[
            df_training_dataset_merged["env_name"] == name_env
        ].shape
    )
    for seed in [0, 1]:
        print(
            df_training_dataset_merged[
                df_training_dataset_merged["env_name"] == name_env
            ]
            .loc[lambda df: df["seed"] == seed]
            .shape
        )
# Out:
# pendulum
# (27, 35)
# (14, 35)
# (13, 35)
# mackey_glass
# (29, 35)
# (16, 35)
# (13, 35)
# vanderpol
# (30, 35)
# (16, 35)
# (14, 35)

# %%
df = df_training_dataset_merged.loc[~df_training_dataset_merged.duplicated()]
for name_env in df_training_dataset_merged["env_name"].unique():
    print(name_env)
    print(df[df["env_name"] == name_env].shape)
    for seed in [0, 1]:
        print(df[df["env_name"] == name_env].loc[lambda df: df["seed"] == seed].shape)
# Out:
# pendulum
# (24, 35)
# (12, 35)
# (12, 35)
# mackey_glass
# (24, 35)
# (12, 35)
# (12, 35)
# vanderpol
# (24, 35)
# (12, 35)
# (12, 35)

# %%
# Compare the data for some duplicates

# Get duplicates ID
for env_name in df_training_dataset_merged["env_name"].unique():
    print(env_name)
    list_duplicates_id = (
        df_training_dataset_merged.loc[
            df_training_dataset_merged.env_name == "pendulum"
        ]
        .loc[lambda df: df.duplicated(keep=False)]
        .index
    )
    print(list_duplicates_id)
    for id in list_duplicates_id:
        print(df_training_dataset_merged.loc[id])
# Out:
# pendulum
# Index(['61af45e340174a0fb2108f54c97ee0f8', '85363c1761704713b8aa3ca2a99c1ae0',
#        '5b07cd03734946dab5ef23210cf15de3', '8ef2a840f1d5445a83e179a5d9c1adee',
#        'b5691377024b40ff9155962485285191', 'f2042ee2b7814da595266ba75a11268c'],
#       dtype='object', name='training_id')
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                 ncdde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                               ncdde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      8a10495b64e5407090d91eb01b46c5a7
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.0
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 61af45e340174a0fb2108f54c97ee0f8, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  ndde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                                ndde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 85363c1761704713b8aa3ca2a99c1ae0, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                 ncdde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                               ncdde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      8a10495b64e5407090d91eb01b46c5a7
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.0
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 5b07cd03734946dab5ef23210cf15de3, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         1.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  node
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        0.0
# model_params_width_size                                                     64.0
# trainer_name                                                                node
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 8ef2a840f1d5445a83e179a5d9c1adee, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         1.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  node
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        0.0
# model_params_width_size                                                     64.0
# trainer_name                                                                node
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: b5691377024b40ff9155962485285191, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  ndde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                                ndde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: f2042ee2b7814da595266ba75a11268c, dtype: object
# mackey_glass
# Index(['61af45e340174a0fb2108f54c97ee0f8', '85363c1761704713b8aa3ca2a99c1ae0',
#        '5b07cd03734946dab5ef23210cf15de3', '8ef2a840f1d5445a83e179a5d9c1adee',
#        'b5691377024b40ff9155962485285191', 'f2042ee2b7814da595266ba75a11268c'],
#       dtype='object', name='training_id')
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                 ncdde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                               ncdde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      8a10495b64e5407090d91eb01b46c5a7
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.0
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 61af45e340174a0fb2108f54c97ee0f8, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  ndde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                                ndde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 85363c1761704713b8aa3ca2a99c1ae0, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                 ncdde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                               ncdde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      8a10495b64e5407090d91eb01b46c5a7
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.0
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 5b07cd03734946dab5ef23210cf15de3, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         1.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  node
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        0.0
# model_params_width_size                                                     64.0
# trainer_name                                                                node
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 8ef2a840f1d5445a83e179a5d9c1adee, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         1.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  node
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        0.0
# model_params_width_size                                                     64.0
# trainer_name                                                                node
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: b5691377024b40ff9155962485285191, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  ndde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                                ndde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: f2042ee2b7814da595266ba75a11268c, dtype: object
# vanderpol
# Index(['61af45e340174a0fb2108f54c97ee0f8', '85363c1761704713b8aa3ca2a99c1ae0',
#        '5b07cd03734946dab5ef23210cf15de3', '8ef2a840f1d5445a83e179a5d9c1adee',
#        'b5691377024b40ff9155962485285191', 'f2042ee2b7814da595266ba75a11268c'],
#       dtype='object', name='training_id')
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                 ncdde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                               ncdde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      8a10495b64e5407090d91eb01b46c5a7
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.0
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 61af45e340174a0fb2108f54c97ee0f8, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  ndde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                                ndde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 85363c1761704713b8aa3ca2a99c1ae0, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                 ncdde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                               ncdde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      8a10495b64e5407090d91eb01b46c5a7
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.0
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 5b07cd03734946dab5ef23210cf15de3, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         1.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  node
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        0.0
# model_params_width_size                                                     64.0
# trainer_name                                                                node
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: 8ef2a840f1d5445a83e179a5d9c1adee, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         1.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  node
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        0.0
# model_params_width_size                                                     64.0
# trainer_name                                                                node
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: b5691377024b40ff9155962485285191, dtype: object
# mlflow_experiment_name                                    2024_08_23_training_v2
# seed                                                                         0.0
# data_normaliser_name                                             standard_normal
# model_name                                                                  ndde
# model_params_activation                                                     relu
# model_params_depth                                                           2.0
# model_params_dropout                                                         0.0
# model_params_final_activation                                           identity
# model_params_n_delays                                                        1.0
# model_params_width_size                                                     64.0
# trainer_name                                                                ndde
# trainer_params_bool_discretize_then_optimize                                True
# trainer_params_lr_final                                                    0.001
# trainer_params_lr_init                                                     0.001
# trainer_params_max_epochs                                                 4000.0
# trainer_params_name_node_interface                                      torchdde
# trainer_params_pct_trajectory_size                                           1.0
# trainer_params_rate_test_set_size                                            0.1
# trainer_params_solver                                                        rk4
# dataset_id                                      6f35c3230f39428c89bda3cae4ad3b7a
# mlflow_experiment_name_dataset                       2024_08_12_training_data_v2
# seed_dataset                                                                 0.0
# data_control_type                                                        uniform
# data_num_steps                                                             100.0
# data_num_trajectories                                                      400.0
# data_type                                                  multiple_trajectories
# env_name                                                                pendulum
# env_params_beta                                                              NaN
# env_params_delay_observation                                                 0.1
# env_params_dict_initial_condition_std                                        0.1
# env_params_dict_initial_condition_type                                    bottom
# env_params_dt                                                                0.1
# env_params_gamma                                                             NaN
# env_params_n                                                                 NaN
# env_params_tau                                                               NaN
# Name: f2042ee2b7814da595266ba75a11268c, dtype: object

# %%
# Get duplicates rows for Pendulum
env_name = "vanderpol"
df_pendulum = df_training_dataset_merged.loc[
    df_training_dataset_merged["env_name"] == "mackey_glass"
]
(df_pendulum.loc[lambda df: df.duplicated(keep=False)].loc[lambda df: df["seed"] == 1])

# Get the index of the duplicates for the given seed
list_duplicates_id = (
    df_pendulum.loc[lambda df: df.duplicated(keep=False)]
    .loc[lambda df: df["seed"] == 1]
    .index
)
list_duplicates_id
# Out:
# Index(['b3d62fd26f2147b89f83a917b03981a1', '92687f61b4d4449f9d5c3544894ec462'], dtype='object', name='training_id')

# %%
# Load trajectory data for bot duplicates

# path_trajectory_data = pathlib.Path(f"{path_mlruns}/{ID_XP}/
# /home/hosseinkhan/Documents/work/phd/git_repositories/control_dde/data/mlruns_ruche_downloaded/8/1a32e7bd4b064953b057f3a8932489eb/generated_data/trainer_data
# Out:
# PosixPath('/home/hosseinkhan/Documents/work/phd/git_repositories/control_dde/data/mlruns_ruche_downloaded/8')
